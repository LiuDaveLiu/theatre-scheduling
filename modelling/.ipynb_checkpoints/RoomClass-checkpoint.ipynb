# %%
import pandas as pd
import numpy as np
import os
import re
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, roc_auc_score, roc_curve, f1_score

# %%
data_path = os.path.join(os.path.dirname(os.getcwd()), "data", "class.csv")
data_path = os.path.join(os.path.dirname(os.getcwd()), "data", "class_mays.csv")
data_path = os.path.join(os.path.dirname(os.getcwd()), "data", "class_loc.csv")

# %%
df = pd.read_csv(data_path)

# %%
df = df[['Scheduled Setup Start', 'Scheduled Cleanup Complete', 'Room', 'Location', 'Primary Surgeon ID', 'Primary Service']]
df['Scheduled Setup Start']=pd.to_datetime(df['Scheduled Setup Start'])
df['Scheduled Cleanup Complete']=pd.to_datetime(df['Scheduled Cleanup Complete'])
df['Scheduled Room Duration']=(df['Scheduled Cleanup Complete']-df['Scheduled Setup Start']).astype('timedelta64[m]')
df = df.dropna()
df = df[df['Room'].str.contains(r'\d', regex=True)]
df = df[df['Location']=='MAIN OR']
# df = df[df['Location']=='MAYS OR']
df['Room']=df.apply(lambda row: int(re.search(r'\d+', row['Room']).group()), axis = 1)
df = df.loc[df['Room']<41]

df['SurgeonID'] = df.groupby('Primary Surgeon ID').ngroup()
df=df.assign(CaseID=range(len(df)))

# %%
X = df[['Primary Surgeon ID', 'Primary Service', 'Scheduled Room Duration']]

# %%
y = df['Room']
# y = df['Location']

# %%
seed = 1  # so that the result is reproducible
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.1, random_state = seed)

# %%
features_to_encode = ['Primary Surgeon ID', 'Primary Service']

# %%
col_trans = make_column_transformer(
                        (OneHotEncoder(),features_to_encode),
                        remainder = "passthrough"
                        )

# %%
rf_classifier = RandomForestClassifier(
                      min_samples_leaf=50,
                      n_estimators=150,
                      bootstrap=True,
                      oob_score=True,
                      n_jobs=-1,
                      random_state=seed,
                      max_features='auto')

# %%
pipe = make_pipeline(col_trans, rf_classifier)
# pipe.fit(X_train, y_train)
pipe.fit(X, y)
# Out:
# Pipeline(memory=None,
#          steps=[('columntransformer',
#                  ColumnTransformer(n_jobs=None, remainder='passthrough',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories='auto',
#                                                                 drop=None,
#                                                                 dtype=<class 'numpy.float64'>,
#                                                                 handle_unknown='error',
#                                                                 sparse=True),
#                                                   ['Primary Surgeon ID',
#                                                    'Primary Service'])],
#                                    verbose=False)),
#                 ('rando...
#                  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                         class_weight=None, criterion='gini',
#                                         max_depth=None, max_features='auto',
#                                         max_leaf_nodes=None, max_samples=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=50,
#                                         min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=150, n_jobs=-1,
#                                         oob_score=True, random_state=1,
#                                         verbose=0, warm_start=False))],
#          verbose=False)

# %%
y_pred = pipe.predict(X)
accuracy_score(y, y_pred)
print(f"The accuracy of the model is {round(accuracy_score(y,y_pred),3)*100} %")
# Out:
# The accuracy of the model is 29.2 %

# %%
import itertools
def plot_confusion_matrix(cm, classes, normalize = False,
                          title='Confusion matrix',
                          cmap=plt.cm.Greens): # can change color 
    plt.figure(figsize = (10, 10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, size = 24)
    plt.colorbar(aspect=4)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, size = 14)
    plt.yticks(tick_marks, classes, size = 14)
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    # Label the plot
    for i, j in itertools.product(range(cm.shape[0]),   range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), fontsize = 8, horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")
        plt.grid(None)
        plt.tight_layout()
        plt.ylabel('True label', size = 8)
        plt.xlabel('Predicted label', size = 8)

# Let's plot it out
cm = confusion_matrix(y, y_pred)
plot_confusion_matrix(cm, classes = [str(i) for i in range(1,37)])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 23
#      20         plt.xlabel('Predicted label', size = 8)
#      22 # Let's plot it out
# ---> 23 cm = confusion_matrix(y_test, y_pred)
#      24 plot_confusion_matrix(cm, classes = [str(i) for i in range(1,37)])
#
# File c:\users\lliu10\anaconda3\envs\lp_pyomo\lib\site-packages\sklearn\metrics\_classification.py:268, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     196 def confusion_matrix(y_true, y_pred, labels=None, sample_weight=None,
#     197                      normalize=None):
#     198     """Compute confusion matrix to evaluate the accuracy of a classification.
#     199
#     200     By definition a confusion matrix :math:`C` is such that :math:`C_{i, j}`
#    (...)
#     266
#     267     """
# --> 268     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     269     if y_type not in ("binary", "multiclass"):
#     270         raise ValueError("%s is not supported" % y_type)
#
# File c:\users\lliu10\anaconda3\envs\lp_pyomo\lib\site-packages\sklearn\metrics\_classification.py:80, in _check_targets(y_true, y_pred)
#      53 def _check_targets(y_true, y_pred):
#      54     """Check that y_true and y_pred belong to the same classification task
#      55
#      56     This converts multiclass or binary types to a common shape, and raises a
#    (...)
#      78     y_pred : array or indicator matrix
#      79     """
# ---> 80     check_consistent_length(y_true, y_pred)
#      81     type_true = type_of_target(y_true)
#      82     type_pred = type_of_target(y_pred)
#
# File c:\users\lliu10\anaconda3\envs\lp_pyomo\lib\site-packages\sklearn\utils\validation.py:211, in check_consistent_length(*arrays)
#     209 uniques = np.unique(lengths)
#     210 if len(uniques) > 1:
# --> 211     raise ValueError("Found input variables with inconsistent numbers of"
#     212                      " samples: %r" % [int(l) for l in lengths])
#
# ValueError: Found input variables with inconsistent numbers of samples: [3089, 30889]

# %%
print(rf_classifier.feature_importances_)
print(f" There are {len(rf_classifier.feature_importances_)} features in total")
# Out:
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  9.99674933e-04 0.00000000e+00 0.00000000e+00 9.08522333e-05
#  7.44275524e-04 8.82463720e-05 3.17151533e-04 6.42142411e-04
#  0.00000000e+00 5.18212241e-04 3.92331839e-05 9.95669028e-04
#  1.76947601e-03 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  3.44173200e-05 2.15854355e-03 9.30267456e-04 1.33017655e-02
#  0.00000000e+00 3.65258143e-04 1.07475499e-05 0.00000000e+00
#  0.00000000e+00 5.18580966e-03 1.33520433e-02 2.44954447e-04
#  2.64327176e-04 2.14741629e-03 0.00000000e+00 0.00000000e+00
#  4.05757733e-02 2.75712186e-03 0.00000000e+00 9.29043859e-05
#  2.76516457e-03 2.21223247e-03 0.00000000e+00 5.17701303e-04
#  2.76352273e-04 2.28767887e-04 7.49991300e-05 8.19978980e-04
#  3.33896287e-02 4.68812640e-04 3.56433229e-03 2.50315120e-04
#  1.46329393e-04 3.23986901e-04 0.00000000e+00 0.00000000e+00
#  1.19113852e-03 3.69032533e-04 0.00000000e+00 1.23246735e-04
#  0.00000000e+00 9.87027535e-05 1.32010986e-03 0.00000000e+00
#  0.00000000e+00 6.79388651e-03 7.84264655e-03 1.67183803e-02
#  0.00000000e+00 1.79386664e-04 0.00000000e+00 0.00000000e+00
-05 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.42114948e-02 1.72040820e-02 0.00000000e+00 0.00000000e+00
#  7.94747370e-02 6.10645241e-02 3.43347021e-02 5.67630761e-02
#  4.94790670e-02 4.32786534e-03 3.52906417e-02 0.00000000e+00
#  4.42491022e-02 3.39062519e-02 0.00000000e+00 0.00000000e+00
#  8.86198076e-03 1.68530140e-04 9.18114361e-03 4.66808571e-03
#  2.08090873e-03 6.70965427e-03 5.68024434e-03 1.04461075e-02
#  1.94154763e-03 0.00000000e+00 9.82543973e-04 4.69722419e-02
#  0.00000000e+00 3.47154797e-02 7.15311380e-02]
#  There are 343 features in total

# %%
def encode_and_bind(original_dataframe, features_to_encode):
    dummies = pd.get_dummies(original_dataframe[features_to_encode])
    res = pd.concat([dummies, original_dataframe], axis=1)
    res = res.drop(features_to_encode, axis=1)
    return(res)
X_train_encoded = encode_and_bind(X_train, features_to_encode)

# %%
feature_importances = list(zip(X_train_encoded, rf_classifier.feature_importances_))
# Then sort the feature importances by most important first
feature_importances_ranked = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances
[print('Feature: {:35} Importance: {}'.format(*pair)) for pair in feature_importances_ranked];
# Out:
# Feature: Primary Service_PAIN SERVICE        Importance: 0.22999627044833093
# Feature: Primary Service_THRCV - VASCULAR SURGERY Importance: 0.02336055011851529
# Feature: Primary Service_BREAST              Importance: 0.004408453566646678
# Feature: Primary Service_SURG ONC - SARCOMA  Importance: 0.0024184518055079666
# Feature: Scheduled Room Duration             Importance: 0.0020364989767963147
# Feature: Primary Service_THRCV - THORACIC SURGERY Importance: 0.0017312577040505608
# Feature: Primary Service_GYN - GENERAL GYNECOLOGY Importance: 0.001169468852946631
# Feature: Primary Service_UROLOGY             Importance: 0.000830435646767405
# Feature: Primary Service_SURG ONC - MELANOMA Importance: 0.0008215289376787023
# Feature: Primary Service_HN - HEAD & NECK SURGERY Importance: 0.0007975713759775882
# Feature: Primary Service_RADIATION ONCOLOGY  Importance: 0.00031500774003195717
# Feature: Primary Service_SURG ONC - PORT     Importance: 0.00027492122706943055
# Feature: Primary Service_COLON & RECTAL SURGERY Importance: 0.00026274064607114783
# Feature: Primary Service_GYN - GYNECOLOGIC ONCOLOGY Importance: 0.0
# Feature: Primary Service_OPHTHALMOLOGY       Importance: 0.0
# Feature: Primary Service_PLS - PLASTIC SURGERY Importance: 0.0
# Feature: Primary Service_SURG ONC - ENDOCRINE Importance: 0.0
# Feature: Primary Service_SURG ONC - GENERAL  Importance: 0.0

# %%
feature_names_25 = [i[0] for i in feature_importances_ranked[:25]]
y_ticks = np.arange(0, len(feature_names_25))
x_axis = [i[1] for i in feature_importances_ranked[:25]]
plt.figure(figsize = (10, 14))
plt.barh(feature_names_25, x_axis)   #horizontal barplot
plt.title('Random Forest Feature Importance',
          fontdict= {'fontname':'Comic Sans MS','fontsize' : 20})
plt.xlabel('Features',fontdict= {'fontsize' : 16})
plt.show()
